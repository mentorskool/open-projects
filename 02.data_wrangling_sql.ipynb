# %%
#@title 
# %%html
<marquee style='width: 100%; color: #4788f4;font-size:30px;'><b>Welcome to Mentorskool!</b></marquee>
# Out:
# <marquee style='width: 100%; color: #4788f4;font-size:30px;'><b>Welcome to Mentorskool!</b></marquee>

# %% [markdown]
# ## **MentorClass - 03 | Writing some SQL Code**
# -----
# We'll be working on below topics in this class :
#
# * Connecting to **SQL Server Database**
# * Do some **code gyms** while trying to answer business questions
# * Summarizing our learnings (**Very Important!**)

# %%
#@title <b>Connecting to SQL Server Database
from IPython.display import YouTubeVideo
YouTubeVideo('QP6UlHhNnPI',width=800, height=500)

# %% [markdown]
# ### **Writing some code now!**

# %% [markdown]
# * Let's look at below questions
# * Each question would require you to write an SQL query to fetch data in the required output format
# * Save all your queries as a .sql file with format : **your_email_id_without_domain.sql**
# * Ex. if your email ID is **john.doe@gmail.com** then name your .sql file as **john.doe.sql**
# * Submit your solution in **Google Classroom**

# %% [markdown]
# Head towards your **SQL Server Management Studio** client, connect to the database as shown in video above and start coding!
#
# Why wait? Let's **CODE**!

# %% [markdown]
# #### **Question 1 :**
# How many sales transactions took place in Jun'16? <br>
# * *List all the transactions as a table*
# -------------------

# %% [markdown]
# #### **Question 2 :**
# Show year wise profit margin<br>
# * *Profit Margin should be shown as percentage*
# * *It should be rounded off to 2 decimal places*
# ------------------------------

# %% [markdown]
# #### **Question 3 :**
# What is the sales trend MoM for last 3 months?
# * Show month wise sales
# * Since the last data point available is for Dec,2017 please consider Oct,Nov and Dec'2017 sales data for the query
#
# ------------------------------

# %% [markdown]
# #### **Question 4 :**
# What change will you do in the query to fetch the same data as above
# for last 6 months and last 12 months?
#
# ------------------------------

# %% [markdown]
# #### **Question 5 :**
# Now, what query will you write if all 3 results above needs to be appended together stacked vertically?
#
# ------------------------------

# %% [markdown]
# #### **Question 6 :**
# Let's try and make the total sales look more formatted. Continuing from Question 3 :
#   * Format Sales column to have :
#     * 2 decimal points
#     * Append a $ symbol in the beginning
#     * Add a million comma separator for sales
#
# ------------------------------

# %% [markdown]
# #### **Question 7 :**
# Which are the top 3 sub-categories by sales?
#
# ------------------------------

# %% [markdown]
# #### **Question 8 :**
# Calculate sales contribution% for each of the category by state
#
# ------------------------------

# %% [markdown]
# ### **Video Questions**

# %%
|#@title <b>Question : 1
from IPython.display import YouTubeVideo
YouTubeVideo('Psw_cqLG6uI',width=900, height=500)

# %%
#@title <b>Question : 2
from IPython.display import YouTubeVideo
YouTubeVideo('0hy2C-h2IyI',width=900, height=500)

# %%
#@title <b>Question : 3
from IPython.display import YouTubeVideo
YouTubeVideo('5c4DCTLet7A',width=900, height=500)

# %%
#@title <b>Question : 4
from IPython.display import YouTubeVideo
YouTubeVideo('ZtPr8346kiU',width=900, height=500)

# %%
#@title <b>Question : 5
from IPython.display import YouTubeVideo
YouTubeVideo('N-vNHXFyi7s',width=900, height=500)

# %% [markdown]
# -------------------------------------
# ### **Questions to think upon!**
# *(need not write query)* <br><br>
# **Question :** Does the sales show any seasonality YoY?Which category is selling more? <br>
# **Answer :**
# <br><br>
# **Question :** Which are the top 10 fastest/slowest moving products? <br>
# **Answer** <br><br>
# **Question :** Which vendors have high rate of on or before time deliveries? <br>
# **Answer :**
# Which vendors have high rate of delayed deliveries?
#
# **Question :** Which vendors are most consistent in deliveries (consistently good or bad) in last 6 months) <br>
# **Answer :** <br><br>
# **Question :** What % of high priority orders are getting delayed? <br>
# **Answer :** <br><br>
# **Question :** Which vendors are most consistent in deliveries (consistently good or bad) in last 6 months) <br>
# **Answer :** <br><br>
# **Question :** Which are the top 10 states by #customers ordering from? <br>
# **Answer :** <br><br>
# **Question :** Which region exhibits most repeat orders? <br>
# **Answer :** <br><br>
# **Question :** Which categories/sub-categories are showing highest returns? <br>
# **Answer :** <br><br>
# **Question :** Are returns high in high-ticket or low-ticket items? <br>
# **Answer :** <br><br>
